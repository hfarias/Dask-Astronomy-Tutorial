# %%
from dask.distributed import Client

# %%
client = Client('scheduler:8786')
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/distributed/comm/core.py in connect(addr, timeout, deserialize, connection_args)
#     185                                           future,
# --> 186                                           quiet_exceptions=EnvironmentError)
#     187         except EnvironmentError as e:
#
# ~/anaconda3/lib/python3.7/site-packages/tornado/gen.py in run(self)
#    1132                     try:
# -> 1133                         value = future.result()
#    1134                     except Exception:
#
# TimeoutError: Timeout
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-3-7d0abfc0da2e> in <module>()
# ----> 1 client = Client('scheduler:8786')
#
# ...

# %%
client.ncores()
